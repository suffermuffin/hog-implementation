# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im = np.random.randint(0, 255, size=(128, 64))
ax = plt.imshow(im)

# %%
def get_block(im, cell_size, block_size, upper_left):

    cell_size = 8 # количество пикселей вдоль осей клетки
    block_size = 4  # количество клеток в блоке
    fig, axs = plt.subplots(16, 8, sharex=True, sharey=True, figsize=(10, 20))
    for i, y in enumerate(range(0, 128, cell_size)):
        for j, x in enumerate(range(0, 64, cell_size)):
            cell = im[y:y + cell_size, x:x + cell_size]
            axs[i,j].imshow(cell)
